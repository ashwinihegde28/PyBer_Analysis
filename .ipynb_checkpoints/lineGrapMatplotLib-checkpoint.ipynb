# %%
import matplotlib.pyplot as plt

#check the version
matplotlib.__version__
# Out:
# '3.4.3'

# %%
savings=[0,100,200,300,500,300,600,800,1200,1000,300,800]
months=["Jan","Feb","mar","Apr","may","Jun","Jly","aug","Sep","Oct","Nov","Dec"]

# %%
plt.plot(months,savings)
plt.xlabel("Month")
plt.ylabel("Savings ($)")
plt.title("Saving Account results")
plt.show()
